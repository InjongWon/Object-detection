# %%
import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.optim as optim
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
from torch.optim.lr_scheduler import StepLR
import torch.nn.functional as F
# %matplotlib inline
import torch.nn as nn
from torchvision.models import resnet18, ResNet18_Weights, resnet34, resnext50_32x4d
from torch.optim.lr_scheduler import StepLR

# used source from: https://pytorch.org/hub/pytorch_vision_resnext/
#cuda sematic:https://pytorch.org/docs/stable/notes/cuda.html

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
    
])

# %%
#for both DBI&SSD data path in drive
# !unzip -q -o "/content/drive/MyDrive/DBIsubset.zip" -d "/content/"
# !unzip -o "/content/drive/MyDrive/SSDsubset.zip" -d "/content/"
# !unzip -q -j "/content/drive/MyDrive/DBIsubset.zip" -d "/content/DBIsubset/"
# !unzip -q -j "/content/drive/MyDrive/SSDsubset.zip" -d "/content/SSDsubset/"


# !find /content/ -name "__MACOSX" -exec rm -rf {} +
# !find /content/ -name "._*" -exec rm -rf {} +
# !find /content/ -name ".DS_Store" -exec rm -rf {} +
# !find /content/ -name ".*" -exec rm -rf {} +
# !ls /content/DBIsubset

path1 = '/content/DBIsubset'
path2 = '/content/SSDsubset'
DBIDATA = ImageFolder(path1, transform=transform)
SSDDATA = ImageFolder(path2, transform=transform)
# Out:
# replace /content/DBIsubset/chihuahua14.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# replace /content/SSDsubset/n02099601_1028.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# rm: cannot remove '/content/drive/.shortcut-targets-by-id': Operation canceled
# rm: cannot remove '/content/drive/.file-revisions-by-id': Operation canceled
# rm: cannot remove '/content/drive/.Trash-0': Directory not empty
# rm: cannot remove '/content/drive/.Encrypted/MyDrive': Operation canceled
# rm: cannot remove '/content/drive/.Encrypted/.shortcut-targets-by-id': Operation canceled
# rm: cannot remove '/content/drive/.Encrypted/.shortcut-targets-by-id': Operation canceled
# bernese100.jpg	      chihuahua3.jpg   collie78.jpg	 husky32.jpg	  labrador6.jpg
# bernese10.jpg	      chihuahua40.jpg  collie7.jpg	 husky33.jpg	  labrador70.jpg
# bernese11.jpg	      chihuahua41.jpg  collie80.jpg	 husky34.jpg	  labrador71.jpg
# bernese12.jpg	      chihuahua42.jpg  collie81.jpg	 husky35.jpg	  labrador72.jpg
# bernese13.jpg	      chihuahua44.jpg  collie82.jpg	 husky36.jpg	  labrador73.jpg
# bernese14.jpg	      chihuahua45.jpg  collie84.jpg	 husky37.jpg	  labrador74.jpg
# bernese15.jpg	      chihuahua46.jpg  collie85.jpg	 husky38.jpg	  labrador75.jpg
# bernese16.jpg	      chihuahua47.jpg  collie86.jpg	 husky39.jpg	  labrador76.jpg
# bernese17.jpg	      chihuahua48.jpg  collie87.jpg	 husky3.jpg	  labrador77.jpg
# bernese18.jpg	      chihuahua49.jpg  collie89.jpg	 husky40.jpg	  labrador78.jpg
# bernese19.jpg	      chihuahua4.jpg   collie8.jpg	 husky41.jpg	  labrador79.jpg
# bernese1.jpg	      chihuahua50.jpg  collie90.jpg	 husky42.jpg	  labrador7.jpg
# bernese20.jpg	      chihuahua51.jpg  collie91.jpg	 husky45.jpg	  labrador80.jpg
# bernese21.jpg	      chihuahua52.jpg  collie92.jpg	 husky46.jpg	  labrador81.jpg
# bernese22.jpg	      chihuahua54.jpg  collie93.jpg	 husky47.jpg	  labrador82.jpg
# bernese23.jpg	      chihuahua55.jpg  collie94.jpg	 husky48.jpg	  labrador83.jpg
# bernese24.jpg	      chihuahua56.jpg  collie95.jpg	 husky49.jpg	  labrador85.jpg
# bernese25.jpg	      chihuahua58.jpg  collie96.jpg	 husky4.jpg	  labrador86.jpg
# bernese26.jpg	      chihuahua59.jpg  collie97.jpg	 husky50.jpg	  labrador87.jpg
# bernese27.jpg	      chihuahua5.jpg   collie98.jpg	 husky51.jpg	  labrador88.jpg
# bernese28.jpg	      chihuahua61.jpg  collie99.jpg	 husky52.jpg	  labrador89.jpg
# bernese29.jpg	      chihuahua62.jpg  collie9.jpg	 husky53.jpg	  labrador8.jpg
# bernese2.jpg	      chihuahua63.jpg  golden_retriever  husky54.jpg	  labrador90.jpg
# bernese30.jpg	      chihuahua64.jpg  gr100.jpg	 husky55.jpg	  labrador91.jpg
# bernese31.jpg	      chihuahua65.jpg  gr10.jpg		 husky56.jpg	  labrador92.jpg
# bernese32.jpg	      chihuahua66.jpg  gr11.jpg		 husky57.jpg	  labrador93.jpg
# bernese33.jpg	      chihuahua68.jpg  gr12.jpg		 husky58.jpg	  labrador94.jpg
# bernese34.jpg	      chihuahua69.jpg  gr13.jpg		 husky59.jpg	  labrador95.jpg
# bernese35.jpg	      chihuahua6.jpg   gr14.jpg		 husky5.jpg	  labrador96.jpg
# bernese36.jpg	      chihuahua70.jpg  gr15.jpg		 husky60.jpg	  labrador97.jpg
# bernese37.jpg	      chihuahua71.jpg  gr16.jpg		 husky61.jpg	  labrador98.jpg
# bernese38.jpg	      chihuahua72.jpg  gr17.jpg		 husky62.jpg	  labrador99.jpg
# bernese39.jpg	      chihuahua73.jpg  gr18.jpg		 husky63.jpg	  labrador_retriever
# bernese3.jpg	      chihuahua74.jpg  gr19.jpg		 husky64.jpg	  pug
# bernese40.jpg	      chihuahua75.jpg  gr20.jpg		 husky66.jpg	  pug100.jpg
# bernese41.jpg	      chihuahua76.jpg  gr21.jpg		 husky67.jpg	  pug10.jpg
# bernese42.jpg	      chihuahua77.jpg  gr22.jpg		 husky68.jpg	  pug11.jpg
# bernese43.jpg	      chihuahua78.jpg  gr23.jpg		 husky69.jpg	  pug12.jpg
# bernese44.jpg	      chihuahua79.jpg  gr25.jpg		 husky6.jpg	  pug13.jpg
# bernese45.jpg	      chihuahua7.jpg   gr26.jpg		 husky70.jpg	  pug14.jpg
# bernese46.jpg	      chihuahua80.jpg  gr29.jpg		 husky71.jpg	  pug15.jpg
# bernese47.jpg	      chihuahua81.jpg  gr30.jpg		 husky72.jpg	  pug16.jpg
# bernese48.jpg	      chihuahua82.jpg  gr32.jpg		 husky73.jpg	  pug17.jpg
# bernese49.jpg	      chihuahua83.jpg  gr34.jpg		 husky74.jpg	  pug18.jpg
# bernese4.jpg	      chihuahua84.jpg  gr35.jpg		 husky75.jpg	  pug19.jpg
# bernese50.jpg	      chihuahua85.jpg  gr37.jpg		 husky76.jpg	  pug20.jpg
# bernese51.jpg	      chihuahua86.jpg  gr39.jpg		 husky77.jpg	  pug21.jpg
# bernese52.jpg	      chihuahua88.jpg  gr3.jpg		 husky78.jpg	  pug23.jpg
# bernese54.jpg	      chihuahua89.jpg  gr40.jpg		 husky79.jpg	  pug24.jpg
# bernese55.jpg	      chihuahua8.jpg   gr41.jpg		 husky7.jpg	  pug25.jpg
# bernese56.jpg	      chihuahua91.jpg  gr42.jpg		 husky80.jpg	  pug26.jpg
# bernese57.jpg	      chihuahua92.jpg  gr43.jpg		 husky81.jpg	  pug27.jpg
# bernese58.jpg	      chihuahua93.jpg  gr44.jpg		 husky82.jpg	  pug28.jpg
# bernese59.jpg	      chihuahua94.jpg  gr46.jpg		 husky83.jpg	  pug29.jpg
# bernese5.jpg	      chihuahua95.jpg  gr47.jpg		 husky84.jpg	  pug2.jpg
# bernese60.jpg	      chihuahua96.jpg  gr48.jpg		 husky85.jpg	  pug30.jpg
# bernese61.jpg	      chihuahua97.jpg  gr49.jpg		 husky86.jpg	  pug31.jpg
# bernese63.jpg	      chihuahua98.jpg  gr50.jpg		 husky87.jpg	  pug32.jpg
# bernese64.jpg	      chihuahua99.jpg  gr51.jpg		 husky88.jpg	  pug33.jpg
# bernese65.jpg	      chihuahua9.jpg   gr52.jpg		 husky89.jpg	  pug34.jpg
# bernese66.jpg	      collie100.jpg    gr53.jpg		 husky8.jpg	  pug35.jpg
# bernese67.jpg	      collie10.jpg     gr54.jpg		 husky90.jpg	  pug37.jpg
# bernese68.jpg	      collie11.jpg     gr55.jpg		 husky91.jpg	  pug38.jpg
# bernese6.jpg	      collie12.jpg     gr56.jpg		 husky92.jpg	  pug39.jpg
# bernese70.jpg	      collie13.jpg     gr57.jpg		 husky93.jpg	  pug3.jpg
# bernese71.jpg	      collie14.jpg     gr58.jpg		 husky94.jpg	  pug40.jpg
# bernese72.jpg	      collie15.jpg     gr59.jpg		 husky95.jpg	  pug41.jpg
# bernese73.jpg	      collie16.jpg     gr5.jpg		 husky96.jpg	  pug42.jpg
# bernese74.jpg	      collie17.jpg     gr60.jpg		 husky97.jpg	  pug44.jpg
# bernese75.jpg	      collie18.jpg     gr61.jpg		 husky99.jpg	  pug45.jpg
# bernese76.jpg	      collie19.jpg     gr62.jpg		 labrador100.jpg  pug46.jpg
# bernese77.jpg	      collie1.jpg      gr63.jpg		 labrador12.jpg   pug47.jpg
# bernese78.jpg	      collie20.jpg     gr64.jpg		 labrador13.jpg   pug48.jpg
# bernese79.jpg	      collie22.jpg     gr65.jpg		 labrador15.jpg   pug49.jpg
# bernese7.jpg	      collie23.jpg     gr66.jpg		 labrador16.jpg   pug50.jpg
# bernese80.jpg	      collie24.jpg     gr69.jpg		 labrador17.jpg   pug51.jpg
# bernese81.jpg	      collie25.jpg     gr70.jpg		 labrador18.jpg   pug52.jpg
# bernese82.jpg	      collie28.jpg     gr71.jpg		 labrador19.jpg   pug53.jpg
# bernese83.jpg	      collie29.jpg     gr72.jpg		 labrador20.jpg   pug54.jpg
# bernese84.jpg	      collie2.jpg      gr73.jpg		 labrador21.jpg   pug55.jpg
# bernese86.jpg	      collie30.jpg     gr74.jpg		 labrador22.jpg   pug56.jpg
# bernese87.jpg	      collie31.jpg     gr75.jpg		 labrador23.jpg   pug57.jpg
# bernese88.jpg	      collie32.jpg     gr76.jpg		 labrador24.jpg   pug58.jpg
# bernese89.jpg	      collie33.jpg     gr77.jpg		 labrador25.jpg   pug59.jpg
# bernese8.jpg	      collie34.jpg     gr78.jpg		 labrador26.jpg   pug5.jpg
# bernese90.jpg	      collie35.jpg     gr79.jpg		 labrador27.jpg   pug60.jpg
# bernese91.jpg	      collie36.jpg     gr7.jpg		 labrador28.jpg   pug61.jpg
# bernese92.jpg	      collie37.jpg     gr80.jpg		 labrador29.jpg   pug62.jpg
# bernese93.jpg	      collie38.jpg     gr82.jpg		 labrador2.jpg	  pug63.jpg
# bernese94.jpg	      collie39.jpg     gr84.jpg		 labrador30.jpg   pug64.jpg
# bernese95.jpg	      collie3.jpg      gr85.jpg		 labrador31.jpg   pug66.jpg
# bernese96.jpg	      collie40.jpg     gr86.jpg		 labrador32.jpg   pug67.jpg
# bernese97.jpg	      collie41.jpg     gr87.jpg		 labrador33.jpg   pug68.jpg
# bernese98.jpg	      collie42.jpg     gr88.jpg		 labrador34.jpg   pug69.jpg
# bernese99.jpg	      collie43.jpg     gr89.jpg		 labrador35.jpg   pug6.jpg
# bernese9.jpg	      collie44.jpg     gr8.jpg		 labrador36.jpg   pug70.jpg
# bernese_mountain_dog  collie45.jpg     gr90.jpg		 labrador37.jpg   pug71.jpg
# border_collie	      collie46.jpg     gr91.jpg		 labrador38.jpg   pug72.jpg
# chihuahua	      collie47.jpg     gr92.jpg		 labrador39.jpg   pug73.jpg
# chihuahua100.jpg      collie48.jpg     gr93.jpg		 labrador3.jpg	  pug74.jpg
# chihuahua10.jpg       collie49.jpg     gr94.jpg		 labrador40.jpg   pug75.jpg
# chihuahua11.jpg       collie4.jpg      gr95.jpg		 labrador41.jpg   pug76.jpg
# chihuahua12.jpg       collie50.jpg     gr96.jpg		 labrador42.jpg   pug77.jpg
# chihuahua13.jpg       collie51.jpg     gr98.jpg		 labrador43.jpg   pug78.jpg
# chihuahua14.jpg       collie52.jpg     gr99.jpg		 labrador44.jpg   pug79.jpg
# chihuahua15.jpg       collie53.jpg     gr9.jpg		 labrador45.jpg   pug7.jpg
# chihuahua16.jpg       collie54.jpg     husky100.jpg	 labrador46.jpg   pug80.jpg
# chihuahua17.jpg       collie55.jpg     husky10.jpg	 labrador47.jpg   pug81.jpg
# chihuahua18.jpg       collie56.jpg     husky11.jpg	 labrador48.jpg   pug82.jpg
# chihuahua19.jpg       collie57.jpg     husky12.jpg	 labrador4.jpg	  pug83.jpg
# chihuahua1.jpg	      collie58.jpg     husky13.jpg	 labrador50.jpg   pug84.jpg
# chihuahua20.jpg       collie59.jpg     husky14.jpg	 labrador51.jpg   pug85.jpg
# chihuahua21.jpg       collie5.jpg      husky15.jpg	 labrador52.jpg   pug86.jpg
# chihuahua22.jpg       collie60.jpg     husky16.jpg	 labrador53.jpg   pug87.jpg
# chihuahua23.jpg       collie61.jpg     husky17.jpg	 labrador54.jpg   pug88.jpg
# chihuahua24.jpg       collie62.jpg     husky18.jpg	 labrador55.jpg   pug89.jpg
# chihuahua25.jpg       collie63.jpg     husky19.jpg	 labrador56.jpg   pug8.jpg
# chihuahua26.jpg       collie64.jpg     husky1.jpg	 labrador57.jpg   pug90.jpg
# chihuahua27.jpg       collie65.jpg     husky20.jpg	 labrador58.jpg   pug91.jpg
# chihuahua28.jpg       collie66.jpg     husky21.jpg	 labrador59.jpg   pug92.jpg
# chihuahua29.jpg       collie67.jpg     husky22.jpg	 labrador5.jpg	  pug93.jpg
# chihuahua2.jpg	      collie68.jpg     husky23.jpg	 labrador60.jpg   pug94.jpg
# chihuahua30.jpg       collie69.jpg     husky24.jpg	 labrador61.jpg   pug95.jpg
# chihuahua32.jpg       collie6.jpg      husky25.jpg	 labrador62.jpg   pug96.jpg
# chihuahua33.jpg       collie70.jpg     husky26.jpg	 labrador63.jpg   pug97.jpg
# chihuahua34.jpg       collie71.jpg     husky27.jpg	 labrador64.jpg   pug98.jpg
# chihuahua35.jpg       collie72.jpg     husky28.jpg	 labrador65.jpg   pug99.jpg
# chihuahua36.jpg       collie73.jpg     husky29.jpg	 labrador66.jpg   pug9.jpg
# chihuahua37.jpg       collie74.jpg     husky2.jpg	 labrador67.jpg   siberian_husky
# chihuahua38.jpg       collie75.jpg     husky30.jpg	 labrador68.jpg
# chihuahua39.jpg       collie76.jpg     husky31.jpg	 labrador69.jpg

# %%
batch = 32
dbi_train_size = int(0.7 * len(DBIDATA))
dbi_val_size = int(0.15 * len(DBIDATA))
dbi_test_size = len(DBIDATA) - dbi_train_size - dbi_val_size
print("DBI folder:", DBIDATA.classes)
print("SDD folder:", SSDDATA.classes)

train_size = int(0.7 * len(DBIDATA))
val_size = int(0.15 * len(DBIDATA))
test_size = len(DBIDATA) - dbi_train_size - dbi_val_size

#DBI
dbi_train, dbi_val, dbi_test = random_split(DBIDATA, [dbi_train_size, dbi_val_size, dbi_test_size])

dbi_train_loader = DataLoader(dbi_train, batch_size = batch, shuffle=True)
dbi_val_loader = DataLoader(dbi_val, batch_size = batch, shuffle=False)
dbi_test_loader = DataLoader(dbi_test, batch_size=batch, shuffle=False)

#SSD
ssd_loader = DataLoader(SSDDATA, batch_size=batch, shuffle=False)

print("SSDLOADER:", ssd_loader)
pre_trained_models = {
    "ResNet18": resnet18(weights='IMAGENET1K_V1'),
    "ResNet34": resnet34(weights='IMAGENET1K_V1'),
    "ResNeXt32": resnext50_32x4d(weights='IMAGENET1K_V1')
}
# Out:
# DBI folder: ['bernese_mountain_dog', 'border_collie', 'chihuahua', 'golden_retriever', 'labrador_retriever', 'pug', 'siberian_husky']
# SDD folder: ['n02085620-Chihuahua', 'n02099601-golden_retriever', 'n02099712-Labrador_retriever', 'n02106166-Border_collie', 'n02107683-Bernese_mountain_dog', 'n02110185-Siberian_husky', 'n02110958-pug']
# SSDLOADER: <torch.utils.data.dataloader.DataLoader object at 0x78e3876137d0>

# %%
from logging import lastResort
def fineTune(model, train_loader, val_loader, ssd_loader, total_class):

  rate = 0.0001

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr= rate)
  scheduler = StepLR(optimizer, step_size = 5, gamma = 0.1)

  train_acc, validate_acc = [], []
  for epoch in range(10):
      model.train()
      total, valid_trainm, correct = 0, 0,0

      for img, labels in train_loader:
        img, labels = img.to(device), labels.to(device)
        optimizer.zero_grad()

        to_return = model(img)
        loss = criterion(to_return, labels)
        loss.backward()
        optimizer.step()

        _, preds = torch.max(to_return.data, 1)
        total += labels.size(0)
        correct += (preds == labels).sum().item()

      scheduler.step()

      train_accuracy = 100 * correct /total
      train_acc.append(train_accuracy)


      #for validation now
      model.eval()
      total_v, valid_v= 0, 0
      with torch.no_grad():
        for img_v, labels_v in val_loader:
            img_v, val_labels = img_v.to(device), labels_v.to(device)
            val_outputs = model(img_v)
            _, preds_v = torch.max(val_outputs.data, 1)
            total_v += val_labels.size(0)
            valid_v += (preds_v == labels_v).sum().item()

      epoch_val_acc = 100 * valid_v / total_v
      validate_acc.append(epoch_val_acc)
      print(f'Epoch [{epoch+1}/10], Train-Acc: {train_accuracy:.2f}%, Validation-Acc: {epoch_val_acc:.2f}%')

  def eval(loader):
    model.eval()
    correct, total = 0,0
    with torch.no_grad():
      for img, labels in loader:
        img, labels = img.to(device), labels.to(device)
        to_return = model(img)
        _, preds = torch.max(to_return.data, 1)
        total += labels.size(0)
        correct += (preds == labels).sum().item()
    return 100 * correct / total

  dbi_test_acc = eval(dbi_test_loader)
  sdd_acc = eval(ssd_loader)

  print(f"DBI Test Accuracy: {dbi_test_acc:.2f}%")
  print(f"SDD Accuracy: {sdd_acc:.2f}%")

  return dbi_test_acc, sdd_acc

num_classes = len(DBIDATA.classes)
results = {}

for model_name, model in pre_trained_models.items():
  print(f"\nFine-tuning {model_name}...")

# Replace final fully connected layer to match DBI classes
  model.fc = nn.Linear(model.fc.in_features, num_classes)

  dbi_acc, sdd_acc = fineTune(model, dbi_train_loader, dbi_val_loader, ssd_loader, num_classes)
  results[model_name] = {"DBI Test Accuracy": dbi_acc, "SDD Accuracy": sdd_acc}

print("\nCross-Performance Analysis:")
for model_name, metrics in results.items():
  print(f"{model_name}: DBI Test Accuracy = {metrics['DBI Test Accuracy']:.2f}%, SDD Accuracy = {metrics['SDD Accuracy']:.2f}%")
# Out:
# Fine-tuning ResNet18...
# Epoch [1/10], Train-Acc: 71.68%, Validation-Acc: 92.71%
# Epoch [2/10], Train-Acc: 99.56%, Validation-Acc: 94.79%
# Epoch [3/10], Train-Acc: 100.00%, Validation-Acc: 93.75%
# Epoch [4/10], Train-Acc: 100.00%, Validation-Acc: 96.88%
# Epoch [5/10], Train-Acc: 99.34%, Validation-Acc: 94.79%
# Epoch [6/10], Train-Acc: 100.00%, Validation-Acc: 95.83%
# Epoch [7/10], Train-Acc: 100.00%, Validation-Acc: 95.83%
# Epoch [8/10], Train-Acc: 100.00%, Validation-Acc: 93.75%
# Epoch [9/10], Train-Acc: 100.00%, Validation-Acc: 95.83%
# Epoch [10/10], Train-Acc: 100.00%, Validation-Acc: 94.79%
# DBI Test Accuracy: 93.88%
# SDD Accuracy: 1.14%
#
# Fine-tuning ResNet34...
# Epoch [1/10], Train-Acc: 71.90%, Validation-Acc: 95.83%
# Epoch [2/10], Train-Acc: 99.34%, Validation-Acc: 96.88%
# Epoch [3/10], Train-Acc: 98.89%, Validation-Acc: 95.83%
# Epoch [4/10], Train-Acc: 99.56%, Validation-Acc: 95.83%
# Epoch [5/10], Train-Acc: 100.00%, Validation-Acc: 94.79%
# Epoch [6/10], Train-Acc: 100.00%, Validation-Acc: 95.83%
# Epoch [7/10], Train-Acc: 99.56%, Validation-Acc: 93.75%
# Epoch [8/10], Train-Acc: 100.00%, Validation-Acc: 94.79%
# Epoch [9/10], Train-Acc: 99.78%, Validation-Acc: 95.83%
# Epoch [10/10], Train-Acc: 99.78%, Validation-Acc: 93.75%
# DBI Test Accuracy: 94.90%
# SDD Accuracy: 1.62%
#
# Fine-tuning ResNeXt32...
# Epoch [1/10], Train-Acc: 84.29%, Validation-Acc: 95.83%
# Epoch [2/10], Train-Acc: 99.56%, Validation-Acc: 93.75%
# Epoch [3/10], Train-Acc: 99.34%, Validation-Acc: 95.83%
# Epoch [4/10], Train-Acc: 98.89%, Validation-Acc: 93.75%
# Epoch [5/10], Train-Acc: 99.12%, Validation-Acc: 92.71%
# Epoch [6/10], Train-Acc: 99.56%, Validation-Acc: 93.75%
# Epoch [7/10], Train-Acc: 99.56%, Validation-Acc: 92.71%
# Epoch [8/10], Train-Acc: 99.56%, Validation-Acc: 96.88%
# Epoch [9/10], Train-Acc: 99.56%, Validation-Acc: 95.83%
# Epoch [10/10], Train-Acc: 99.56%, Validation-Acc: 96.88%
# DBI Test Accuracy: 94.90%
# SDD Accuracy: 0.32%
#
# Cross-Performance Analysis:
# ResNet18: DBI Test Accuracy = 93.88%, SDD Accuracy = 1.14%
# ResNet34: DBI Test Accuracy = 94.90%, SDD Accuracy = 1.62%
# ResNeXt32: DBI Test Accuracy = 94.90%, SDD Accuracy = 0.32%
